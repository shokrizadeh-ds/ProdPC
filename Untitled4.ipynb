# %%
import skimage

# %%
import numpy as np

# %%
from skimage import io
photo = io.imread('German-Shepherd-on-White-00.jpg')

# %%
type(photo)
# Out:
# imageio.core.util.Array

# %%
photo.shape
# Out:
# (486, 729, 3)

# %%
photo[0]
# Out:
# Array([[255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        ...,
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255]], dtype=uint8)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(photo)

# %%
plt.imshow(photo[::-1])

# %%
plt.imshow(photo[:, ::-1])

# %%
plt.imshow(photo[:-1:])

# %%
plt.imshow(photo)

# %%
plt.imshow(photo[20:268, 160:350])

# %%
plt.imshow(photo[20:268, 160:350][:, ::-1])

# %%
plt.imshow(photo[::2, ::2])

# %%
plt.imshow(photo[::3, ::3])

# %%
plt.imshow(photo[::4, ::4])

# %%
plt.imshow(photo[::5, ::5])

# %%
plt.imshow(photo[::8, ::8])

# %%
plt.imshow(photo[::10, ::10])

# %%
plt.imshow(photo[::20, ::20])

# %%
plt.imshow(np.sin(photo))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x00000234BF3E2DC8> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\_pylab_helpers.py in draw_all(cls, force)
#     126         for f_mgr in cls.get_all_fig_managers():
#     127             if force or f_mgr.canvas.figure.stale:
# --> 128                 f_mgr.canvas.draw_idle()
#     129
#     130 atexit.register(Gcf.destroy_all)
#
# ...

# %%
p = np.abs(np.sin(photo))

# %%
plt.imshow(p)
# Out:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x00000234BF3E2DC8> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\_pylab_helpers.py in draw_all(cls, force)
#     126         for f_mgr in cls.get_all_fig_managers():
#     127             if force or f_mgr.canvas.figure.stale:
# --> 128                 f_mgr.canvas.draw_idle()
#     129
#     130 atexit.register(Gcf.destroy_all)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
# ...

# %%
p.dtype
# Out:
# dtype('float16')

# %%
photo.dtype
# Out:
# dtype('uint8')

# %%
plt.imshow(p.astype('uint8'))

# %%
q = p.astype('uint8') * 255

# %%
plt.imshow(q)

# %%
plt.imshow(photo)

# %%
z = np.array([1, 2, 3, 4, 5, 6])
z
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
z > 3
# Out:
# array([False, False, False,  True,  True,  True])

# %%
z[z > 3]
# Out:
# array([4, 5, 6])

# %%
q_masked = np.where(q < 150, np.abs(np.cos(q)).astype('uint8') / 255 * 150, q)

# %%
plt.imshow(q_masked)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
photo_masked = np.where(photo > 150, 100, 0)

plt.imshow(photo_masked)

# %%
plt.imshow(photo[:, :, 0].T)

# %%
plt.imshow(photo[:, :, 0])

# %%
plt.imshow(photo[:, :, 1])

# %%
plt.imshow(photo[:, :, 2])

# %%
photo[:, :, 2]
# Out:
# Array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
photo[:, :, 2].shape
# Out:
# (486, 729)

# %%
dark_photo = np.where(photo == 255, 0, photo)

# %%
plt.imshow(dark_photo)

# %%
plt.imshow(photo)
