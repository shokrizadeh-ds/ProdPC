# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\LI2BTL'

# %%
import pandas as pd

# %%
data = pd.read_clipboard()

# %%
data
# Out:
#    Type_1 Type_2  Val_1  Val_2  Val_3
# 0       O      O    400    422    319
# 1       J      E    382    189    229
# 2       V      R    370    415    362
# 3       F      Z    433    173    418
# 4       K      E    271    174    142
# 5       D      C    146    129    253
# 6       S      B    290    350    408
# 7       K      K    417    125    358
# 8       E      H    326    405    205
# 9       N      O    323    134    397
# 10      B      N    189    151    343
# 11      F      S    361    147    263
# 12      N      N    272    269    325
# 13      A      B    358    313    377
# 14      N      O    325    261    403
# 15      O      U    411    233    380
# 16      Z      R    274    401    292

# %%
data.shape
# Out:
# (17, 5)

# %%
data.dtypes
# Out:
# Type_1    object
# Type_2    object
# Val_1      int64
# Val_2      int64
# Val_3      int64
# dtype: object

# %%
data.select_dtypes(include='number')
# Out:
#     Val_1  Val_2  Val_3
# 0     400    422    319
# 1     382    189    229
# 2     370    415    362
# 3     433    173    418
# 4     271    174    142
# 5     146    129    253
# 6     290    350    408
# 7     417    125    358
# 8     326    405    205
# 9     323    134    397
# 10    189    151    343
# 11    361    147    263
# 12    272    269    325
# 13    358    313    377
# 14    325    261    403
# 15    411    233    380
# 16    274    401    292

# %%
data.select_dtypes(include='object')
# Out:
#    Type_1 Type_2
# 0       O      O
# 1       J      E
# 2       V      R
# 3       F      Z
# 4       K      E
# 5       D      C
# 6       S      B
# 7       K      K
# 8       E      H
# 9       N      O
# 10      B      N
# 11      F      S
# 12      N      N
# 13      A      B
# 14      N      O
# 15      O      U
# 16      Z      R

# %%
data.Type_1
# Out:
# 0     O
# 1     J
# 2     V
# 3     F
# 4     K
# 5     D
# 6     S
# 7     K
# 8     E
# 9     N
# 10    B
# 11    F
# 12    N
# 13    A
# 14    N
# 15    O
# 16    Z
# Name: Type_1, dtype: object

# %%
data['Type_1']
# Out:
# 0     O
# 1     J
# 2     V
# 3     F
# 4     K
# 5     D
# 6     S
# 7     K
# 8     E
# 9     N
# 10    B
# 11    F
# 12    N
# 13    A
# 14    N
# 15    O
# 16    Z
# Name: Type_1, dtype: object

# %%
data[['Type_1', 'Type_2']]
# Out:
#    Type_1 Type_2
# 0       O      O
# 1       J      E
# 2       V      R
# 3       F      Z
# 4       K      E
# 5       D      C
# 6       S      B
# 7       K      K
# 8       E      H
# 9       N      O
# 10      B      N
# 11      F      S
# 12      N      N
# 13      A      B
# 14      N      O
# 15      O      U
# 16      Z      R

# %%
data[4:8]
# Out:
#   Type_1 Type_2  Val_1  Val_2  Val_3
# 4      K      E    271    174    142
# 5      D      C    146    129    253
# 6      S      B    290    350    408
# 7      K      K    417    125    358

# %%
data[4:8, ['Type_1', 'Type_2']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-2c2bf5e0f1e6> in <module>
# ----> 1 data[4:8, ['Type_1', 'Type_2']]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 )
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#    2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# ...

# %%
data.loc[4:8]
# Out:
#   Type_1 Type_2  Val_1  Val_2  Val_3
# 4      K      E    271    174    142
# 5      D      C    146    129    253
# 6      S      B    290    350    408
# 7      K      K    417    125    358
# 8      E      H    326    405    205

# %%
data.loc[4:8, ['Type_1', 'Val_1', 'Val_3']]
# Out:
#   Type_1  Val_1  Val_3
# 4      K    271    142
# 5      D    146    253
# 6      S    290    408
# 7      K    417    358
# 8      E    326    205

# %%
data.loc[4:8, data.select_dtypes(include='number')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-9288108aac43> in <module>
# ----> 1 data.loc[4:8, data.select_dtypes(include='number')]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1416                 except (KeyError, IndexError, AttributeError):
#    1417                     pass
# -> 1418             return self._getitem_tuple(key)
#    1419         else:
#    1420             # we by definition only have the 0th axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     820                 continue
#     821
# --> 822             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     823
#     824         return retval
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1835
# ...

# %%
data.select_dtypes(include='number')[4:8]
# Out:
#    Val_1  Val_2  Val_3
# 4    271    174    142
# 5    146    129    253
# 6    290    350    408
# 7    417    125    358

# %%
data.select_dtypes(include='object')[5:9]
# Out:
#   Type_1 Type_2
# 5      D      C
# 6      S      B
# 7      K      K
# 8      E      H

# %%
data.rename(columns={'Val_1': 'Med_1'})
# Out:
#    Type_1 Type_2  Med_1  Val_2  Val_3
# 0       O      O    400    422    319
# 1       J      E    382    189    229
# 2       V      R    370    415    362
# 3       F      Z    433    173    418
# 4       K      E    271    174    142
# 5       D      C    146    129    253
# 6       S      B    290    350    408
# 7       K      K    417    125    358
# 8       E      H    326    405    205
# 9       N      O    323    134    397
# 10      B      N    189    151    343
# 11      F      S    361    147    263
# 12      N      N    272    269    325
# 13      A      B    358    313    377
# 14      N      O    325    261    403
# 15      O      U    411    233    380
# 16      Z      R    274    401    292

# %%
data
# Out:
#    Type_1 Type_2  Val_1  Val_2  Val_3
# 0       O      O    400    422    319
# 1       J      E    382    189    229
# 2       V      R    370    415    362
# 3       F      Z    433    173    418
# 4       K      E    271    174    142
# 5       D      C    146    129    253
# 6       S      B    290    350    408
# 7       K      K    417    125    358
# 8       E      H    326    405    205
# 9       N      O    323    134    397
# 10      B      N    189    151    343
# 11      F      S    361    147    263
# 12      N      N    272    269    325
# 13      A      B    358    313    377
# 14      N      O    325    261    403
# 15      O      U    411    233    380
# 16      Z      R    274    401    292

# %%
data.rename(columns={'Val_1': 'Med_1'}, inplace=True)

# %%
data
# Out:
#    Type_1 Type_2  Med_1  Val_2  Val_3
# 0       O      O    400    422    319
# 1       J      E    382    189    229
# 2       V      R    370    415    362
# 3       F      Z    433    173    418
# 4       K      E    271    174    142
# 5       D      C    146    129    253
# 6       S      B    290    350    408
# 7       K      K    417    125    358
# 8       E      H    326    405    205
# 9       N      O    323    134    397
# 10      B      N    189    151    343
# 11      F      S    361    147    263
# 12      N      N    272    269    325
# 13      A      B    358    313    377
# 14      N      O    325    261    403
# 15      O      U    411    233    380
# 16      Z      R    274    401    292

# %%
filt = data.Type_1 == 'N'

# %%
data[filt]
# Out:
#    Type_1 Type_2  Med_1  Val_2  Val_3
# 9       N      O    323    134    397
# 12      N      N    272    269    325
# 14      N      O    325    261    403

# %%
data[filt].Med_1
# Out:
# 9     323
# 12    272
# 14    325
# Name: Med_1, dtype: int64

# %%
data[filt]['Med_1']
# Out:
# 9     323
# 12    272
# 14    325
# Name: Med_1, dtype: int64

# %%
data.Type_1.count()
# Out:
# 17

# %%
data.Type_1
# Out:
# 0     O
# 1     J
# 2     V
# 3     F
# 4     K
# 5     D
# 6     S
# 7     K
# 8     E
# 9     N
# 10    B
# 11    F
# 12    N
# 13    A
# 14    N
# 15    O
# 16    Z
# Name: Type_1, dtype: object

# %%
type(data.Type_1)
# Out:
# pandas.core.series.Series

# %%
data.Type_1[-1:]
# Out:
# 16    Z
# Name: Type_1, dtype: object

# %%
data.Type_1[:3]
# Out:
# 0    O
# 1    J
# 2    V
# Name: Type_1, dtype: object

# %%
data.Type_1.value_counts()
# Out:
# N    3
# O    2
# F    2
# K    2
# D    1
# V    1
# Z    1
# A    1
# B    1
# S    1
# J    1
# E    1
# Name: Type_1, dtype: int64

# %%
data.Type_1.value_counts().sort_index()
# Out:
# A    1
# B    1
# D    1
# E    1
# F    2
# J    1
# K    2
# N    3
# O    2
# S    1
# V    1
# Z    1
# Name: Type_1, dtype: int64

# %%
data.Type_1.value_counts(normalize=True)
# Out:
# N    0.176471
# O    0.117647
# F    0.117647
# K    0.117647
# D    0.058824
# V    0.058824
# Z    0.058824
# A    0.058824
# B    0.058824
# S    0.058824
# J    0.058824
# E    0.058824
# Name: Type_1, dtype: float64

# %%
data.shape
# Out:
# (17, 5)

# %%
data[-1:]
# Out:
#    Type_1 Type_2  Med_1  Val_2  Val_3
# 16      Z      R    274    401    292

# %%
data[17] = ['XX', 'YY', 0, 0, 0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-aac21a948af7> in <module>
# ----> 1 data[17] = ['XX', 'YY', 0, 0, 0]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3470         else:
#    3471             # set column
# -> 3472             self._set_item(key, value)
#    3473
#    3474     def _setitem_slice(self, key, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3547
#    3548         self._ensure_valid_index(value)
# -> 3549         value = self._sanitize_column(key, value)
#    3550         NDFrame._set_item(self, key, value)
#    3551
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3732
#    3733             # turn me into an ndarray
# ...

# %%
data.iloc[-1]
# Out:
# Type_1      Z
# Type_2      R
# Med_1     274
# Val_2     401
# Val_3     292
# Name: 16, dtype: object

# %%
data
# Out:
#    Type_1 Type_2  Med_1  Val_2  Val_3
# 0       O      O    400    422    319
# 1       J      E    382    189    229
# 2       V      R    370    415    362
# 3       F      Z    433    173    418
# 4       K      E    271    174    142
# 5       D      C    146    129    253
# 6       S      B    290    350    408
# 7       K      K    417    125    358
# 8       E      H    326    405    205
# 9       N      O    323    134    397
# 10      B      N    189    151    343
# 11      F      S    361    147    263
# 12      N      N    272    269    325
# 13      A      B    358    313    377
# 14      N      O    325    261    403
# 15      O      U    411    233    380
# 16      Z      R    274    401    292

# %%
data.loc[17] = ['XX', 'YY', 0, 0, 0]

# %%
data.iloc[-1]
# Out:
# Type_1    XX
# Type_2    YY
# Med_1      0
# Val_2      0
# Val_3      0
# Name: 17, dtype: object

# %%
data
# Out:
#    Type_1 Type_2  Med_1  Val_2  Val_3
# 0       O      O    400    422    319
# 1       J      E    382    189    229
# 2       V      R    370    415    362
# 3       F      Z    433    173    418
# 4       K      E    271    174    142
# 5       D      C    146    129    253
# 6       S      B    290    350    408
# 7       K      K    417    125    358
# 8       E      H    326    405    205
# 9       N      O    323    134    397
# 10      B      N    189    151    343
# 11      F      S    361    147    263
# 12      N      N    272    269    325
# 13      A      B    358    313    377
# 14      N      O    325    261    403
# 15      O      U    411    233    380
# 16      Z      R    274    401    292
# 17     XX     YY      0      0      0

# %%
data.loc[17, ['Type_1', 'Val_3']] = ['XX XX', 9999]

# %%
data.iloc[-1]
# Out:
# Type_1    XX XX
# Type_2       YY
# Med_1         0
# Val_2         0
# Val_3      9999
# Name: 17, dtype: object

# %%
data.tail(3)
# Out:
#    Type_1 Type_2  Med_1  Val_2  Val_3
# 15      O      U    411    233    380
# 16      Z      R    274    401    292
# 17  XX XX     YY      0      0   9999

# %%
data.loc[17, 'Type_2'] = 'YY YY'

# %%
data.tail(3)
# Out:
#    Type_1 Type_2  Med_1  Val_2  Val_3
# 15      O      U    411    233    380
# 16      Z      R    274    401    292
# 17  XX XX  YY YY      0      0   9999

# %%
filt
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12     True
# 13    False
# 14     True
# 15    False
# 16    False
# Name: Type_1, dtype: bool

# %%
# filt = data.Type_1 == 'N'

# %%
type(filt)
# Out:
# pandas.core.series.Series

# %%
filt = data.Type_1 == 'N'
data[filt]
# Out:
#    Type_1 Type_2  Med_1  Val_2  Val_3
# 9       N      O    323    134    397
# 12      N      N    272    269    325
# 14      N      O    325    261    403

# %%
data.loc[filt, 'Med_1'] = data.loc[filt, 'Med_1'] * 10

# %%
data[filt]
# Out:
#    Type_1 Type_2  Med_1  Val_2  Val_3
# 9       N      O   3230    134    397
# 12      N      N   2720    269    325
# 14      N      O   3250    261    403

# %%
data
# Out:
#    Type_1 Type_2  Med_1  Val_2  Val_3
# 0       O      O    400    422    319
# 1       J      E    382    189    229
# 2       V      R    370    415    362
# 3       F      Z    433    173    418
# 4       K      E    271    174    142
# 5       D      C    146    129    253
# 6       S      B    290    350    408
# 7       K      K    417    125    358
# 8       E      H    326    405    205
# 9       N      O   3230    134    397
# 10      B      N    189    151    343
# 11      F      S    361    147    263
# 12      N      N   2720    269    325
# 13      A      B    358    313    377
# 14      N      O   3250    261    403
# 15      O      U    411    233    380
# 16      Z      R    274    401    292
# 17  XX XX  YY YY      0      0   9999

# %%
data.loc[17, 'Med_1'] = 1.0

# %%
data.dtypes
# Out:
# Type_1     object
# Type_2     object
# Med_1     float64
# Val_2       int64
# Val_3       int64
# dtype: object

# %%
data
# Out:
#    Type_1 Type_2   Med_1  Val_2  Val_3
# 0       O      O   400.0    422    319
# 1       J      E   382.0    189    229
# 2       V      R   370.0    415    362
# 3       F      Z   433.0    173    418
# 4       K      E   271.0    174    142
# 5       D      C   146.0    129    253
# 6       S      B   290.0    350    408
# 7       K      K   417.0    125    358
# 8       E      H   326.0    405    205
# 9       N      O  3230.0    134    397
# 10      B      N   189.0    151    343
# 11      F      S   361.0    147    263
# 12      N      N  2720.0    269    325
# 13      A      B   358.0    313    377
# 14      N      O  3250.0    261    403
# 15      O      U   411.0    233    380
# 16      Z      R   274.0    401    292
# 17  XX XX  YY YY     1.0      0   9999

# %%
data.loc[17, 'Med_1'] = 'a'

# %%
data
# Out:
#    Type_1 Type_2 Med_1  Val_2  Val_3
# 0       O      O   400    422    319
# 1       J      E   382    189    229
# 2       V      R   370    415    362
# 3       F      Z   433    173    418
# 4       K      E   271    174    142
# 5       D      C   146    129    253
# 6       S      B   290    350    408
# 7       K      K   417    125    358
# 8       E      H   326    405    205
# 9       N      O  3230    134    397
# 10      B      N   189    151    343
# 11      F      S   361    147    263
# 12      N      N  2720    269    325
# 13      A      B   358    313    377
# 14      N      O  3250    261    403
# 15      O      U   411    233    380
# 16      Z      R   274    401    292
# 17  XX XX  YY YY     a      0   9999

# %%
data.dtypes
# Out:
# Type_1    object
# Type_2    object
# Med_1     object
# Val_2      int64
# Val_3      int64
# dtype: object

# %%
data.loc[17, 'Med_1'] = 0

# %%
data
# Out:
#    Type_1 Type_2 Med_1  Val_2  Val_3
# 0       O      O   400    422    319
# 1       J      E   382    189    229
# 2       V      R   370    415    362
# 3       F      Z   433    173    418
# 4       K      E   271    174    142
# 5       D      C   146    129    253
# 6       S      B   290    350    408
# 7       K      K   417    125    358
# 8       E      H   326    405    205
# 9       N      O  3230    134    397
# 10      B      N   189    151    343
# 11      F      S   361    147    263
# 12      N      N  2720    269    325
# 13      A      B   358    313    377
# 14      N      O  3250    261    403
# 15      O      U   411    233    380
# 16      Z      R   274    401    292
# 17  XX XX  YY YY     0      0   9999

# %%
data.dtypes
# Out:
# Type_1    object
# Type_2    object
# Med_1     object
# Val_2      int64
# Val_3      int64
# dtype: object

# %%
data['Med_1'] = data.Med_1.astype('int64')

# %%
data.dtypes
# Out:
# Type_1    object
# Type_2    object
# Med_1      int64
# Val_2      int64
# Val_3      int64
# dtype: object

# %%
data.groupby(['Type_1', 'Type_2']).Med_1.max()
# Out:
# Type_1  Type_2
# A       B          358
# B       N          189
# D       C          146
# E       H          326
# F       S          361
#         Z          433
# J       E          382
# K       E          271
#         K          417
# N       N         2720
#         O         3250
# O       O          400
#         U          411
# S       B          290
# V       R          370
# XX XX   YY YY        0
# Z       R          274
# Name: Med_1, dtype: int64

# %%
data.groupby(['Type_1', 'Type_2']).Med_1.mean()
# Out:
# Type_1  Type_2
# A       B          358
# B       N          189
# D       C          146
# E       H          326
# F       S          361
#         Z          433
# J       E          382
# K       E          271
#         K          417
# N       N         2720
#         O         3240
# O       O          400
#         U          411
# S       B          290
# V       R          370
# XX XX   YY YY        0
# Z       R          274
# Name: Med_1, dtype: int64

# %%
data.groupby(['Type_1', 'Type_2']).Med_1.count()
# Out:
# Type_1  Type_2
# A       B         1
# B       N         1
# D       C         1
# E       H         1
# F       S         1
#         Z         1
# J       E         1
# K       E         1
#         K         1
# N       N         1
#         O         2
# O       O         1
#         U         1
# S       B         1
# V       R         1
# XX XX   YY YY     1
# Z       R         1
# Name: Med_1, dtype: int64

# %%
def quadratic(x):
    return x ** 2

# %%
data.Med_1.apply(quadratic)
# Out:
# 0       160000
# 1       145924
# 2       136900
# 3       187489
# 4        73441
# 5        21316
# 6        84100
# 7       173889
# 8       106276
# 9     10432900
# 10       35721
# 11      130321
# 12     7398400
# 13      128164
# 14    10562500
# 15      168921
# 16       75076
# 17           0
# Name: Med_1, dtype: int64

# %%
data.Med_1
# Out:
# 0      400
# 1      382
# 2      370
# 3      433
# 4      271
# 5      146
# 6      290
# 7      417
# 8      326
# 9     3230
# 10     189
# 11     361
# 12    2720
# 13     358
# 14    3250
# 15     411
# 16     274
# 17       0
# Name: Med_1, dtype: int64

# %%
mn = data.Med_1.mean()
def square_err(x):
    return (x - mn) ** 2

# %%
data.Med_1.apply(square_err)
# Out:
# 0     1.355876e+05
# 1     1.491676e+05
# 2     1.585809e+05
# 3     1.123739e+05
# 4     2.472299e+05
# 5     3.871605e+05
# 6     2.286965e+05
# 7     1.233570e+05
# 8     1.955605e+05
# 9     6.060350e+06
# 10    3.354984e+05
# 11    1.658299e+05
# 12    3.809436e+06
# 13    1.682823e+05
# 14    6.159221e+06
# 15    1.276077e+05
# 16    2.442556e+05
# 17    5.901654e+05
# Name: Med_1, dtype: float64

# %%
data.select_dtypes(include='number').apply(quadratic)
# Out:
#        Med_1   Val_2     Val_3
# 0     160000  178084    101761
# 1     145924   35721     52441
# 2     136900  172225    131044
# 3     187489   29929    174724
# 4      73441   30276     20164
# 5      21316   16641     64009
# 6      84100  122500    166464
# 7     173889   15625    128164
# 8     106276  164025     42025
# 9   10432900   17956    157609
# 10     35721   22801    117649
# 11    130321   21609     69169
# 12   7398400   72361    105625
# 13    128164   97969    142129
# 14  10562500   68121    162409
# 15    168921   54289    144400
# 16     75076  160801     85264
# 17         0       0  99980001

# %%
import numpy as np
data.select_dtypes(include='number').apply(np.mean, axis=1)
# Out:
# 0      380.333333
# 1      266.666667
# 2      382.333333
# 3      341.333333
# 4      195.666667
# 5      176.000000
# 6      349.333333
# 7      300.000000
# 8      312.000000
# 9     1253.666667
# 10     227.666667
# 11     257.000000
# 12    1104.666667
# 13     349.333333
# 14    1304.666667
# 15     341.333333
# 16     322.333333
# 17    3333.000000
# dtype: float64

# %%
data.head(3)
# Out:
#   Type_1 Type_2  Med_1  Val_2  Val_3
# 0      O      O    400    422    319
# 1      J      E    382    189    229
# 2      V      R    370    415    362

# %%
(400 + 422 + 319)/3
# Out:
# 380.3333333333333

# %%
data.tail(3)
# Out:
#    Type_1 Type_2  Med_1  Val_2  Val_3
# 15      O      U    411    233    380
# 16      Z      R    274    401    292
# 17  XX XX  YY YY      0      0   9999

# %%
(0 + 0 + 9999) / 3
# Out:
# 3333.0

# %%
data.select_dtypes(include='number').apply(np.mean)
# Out:
# Med_1    768.222222
# Val_2    238.388889
# Val_3    859.611111
# dtype: float64

# %%
data.Med_1.sum() / len(data.Med_1)
# Out:
# 768.2222222222222

# %%
data.select_dtypes(include='number').shape
# Out:
# (18, 3)

# %%
data.select_dtypes(include='number').head(5)
# Out:
#    Med_1  Val_2  Val_3
# 0    400    422    319
# 1    382    189    229
# 2    370    415    362
# 3    433    173    418
# 4    271    174    142

# %%
# x ** 3 + y ** 2 + z * 15
400 ** 3 + 422 ** 2 + 319 * 15
# Out:
# 64182869

# %%
def cubic(x, y, z):
    return x ** 3 + y ** 2 + z * 15

# %%
cubic(400, 422, 319)
# Out:
# 64182869

# %%
data.select_dtypes(include='number').apply(np.mean, axis='columns')
# Out:
# 0      380.333333
# 1      266.666667
# 2      382.333333
# 3      341.333333
# 4      195.666667
# 5      176.000000
# 6      349.333333
# 7      300.000000
# 8      312.000000
# 9     1253.666667
# 10     227.666667
# 11     257.000000
# 12    1104.666667
# 13     349.333333
# 14    1304.666667
# 15     341.333333
# 16     322.333333
# 17    3333.000000
# dtype: float64

# %%
data.select_dtypes(include='number').apply(cubic, axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-122-1345e532fd69> in <module>
# ----> 1 data.select_dtypes(include='number').apply(cubic, axis=1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6911             kwds=kwds,
#    6912         )
# -> 6913         return op.get_result()
#    6914
#    6915     def applymap(self, func):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     290
#     291         # compute the result using the series generator
# ...

# %%
data.select_dtypes(include='number').shape
# Out:
# (18, 3)

# %%
def cubic(x):
    return x[0] ** 3 + x[1] ** 2 + x[2] * 15

# %%
cubic([400, 422, 319])
# Out:
# 64182869

# %%
data.select_dtypes(include='number').apply(cubic, axis='columns')
# Out:
# 0        64182869
# 1        55782124
# 2        50830655
# 3        81218936
# 4        19934917
# 5         3132572
# 6        24517620
# 7        72532708
# 8        34813076
# 9     33698290911
# 10        6779215
# 11       47071435
# 12    20123725236
# 13       45986336
# 14    34328199166
# 15       69486520
# 16       20736005
# 17         149985
# dtype: int64

# %%
data.tail(5)
# Out:
#    Type_1 Type_2  Med_1  Val_2  Val_3
# 13      A      B    358    313    377
# 14      N      O   3250    261    403
# 15      O      U    411    233    380
# 16      Z      R    274    401    292
# 17  XX XX  YY YY      0      0   9999

# %%
411 ** 3 + 233 ** 2 + 380 * 15
# Out:
# 69486520

# %%
data
# Out:
#    Type_1 Type_2  Med_1  Val_2  Val_3
# 0       O      O    400    422    319
# 1       J      E    382    189    229
# 2       V      R    370    415    362
# 3       F      Z    433    173    418
# 4       K      E    271    174    142
# 5       D      C    146    129    253
# 6       S      B    290    350    408
# 7       K      K    417    125    358
# 8       E      H    326    405    205
# 9       N      O   3230    134    397
# 10      B      N    189    151    343
# 11      F      S    361    147    263
# 12      N      N   2720    269    325
# 13      A      B    358    313    377
# 14      N      O   3250    261    403
# 15      O      U    411    233    380
# 16      Z      R    274    401    292
# 17  XX XX  YY YY      0      0   9999

# %%
data.plot(kind = 'line')

# %%
data.Med_1.plot(kind='hist')

# %%
data.Type_1.value_counts(normalize=True).plot('bar')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: `Series.plot()` should not be called with positional arguments, only keyword arguments. The order of positional arguments will change in the future. Use `Series.plot(kind='bar')` instead of `Series.plot('bar',)`.
#   """Entry point for launching an IPython kernel.

# %%
data.plot(kind='box')

# %%
data.Val_3
# Out:
# 0      319
# 1      229
# 2      362
# 3      418
# 4      142
# 5      253
# 6      408
# 7      358
# 8      205
# 9      397
# 10     343
# 11     263
# 12     325
# 13     377
# 14     403
# 15     380
# 16     292
# 17    9999
# Name: Val_3, dtype: int64

# %%
data.Med_1
# Out:
# 0      400
# 1      382
# 2      370
# 3      433
# 4      271
# 5      146
# 6      290
# 7      417
# 8      326
# 9     3230
# 10     189
# 11     361
# 12    2720
# 13     358
# 14    3250
# 15     411
# 16     274
# 17       0
# Name: Med_1, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.plot(data.Med_1,data.Val_3)

# %%
plt.plot(data.Med_1, data.Med_1.apply(quadratic))

# %%
data['quad'] = data.Med_1.apply(quadratic)

# %%
d = data[['Med_1', 'quad']]

# %%
d
# Out:
#     Med_1      quad
# 0     400    160000
# 1     382    145924
# 2     370    136900
# 3     433    187489
# 4     271     73441
# 5     146     21316
# 6     290     84100
# 7     417    173889
# 8     326    106276
# 9    3230  10432900
# 10    189     35721
# 11    361    130321
# 12   2720   7398400
# 13    358    128164
# 14   3250  10562500
# 15    411    168921
# 16    274     75076
# 17      0         0

# %%
d = d.sort_values('Med_1')

# %%
plt.plot(d)

# %%
data.groupby(['Type_1', 'Type_1']).Val_1.mean()
# Out:
# Type_1  Type_1
# A       A         358.000000
# B       B         189.000000
# D       D         146.000000
# E       E         326.000000
# F       F         397.000000
# J       J         382.000000
# K       K         344.000000
# N       N         306.666667
# O       O         405.500000
# S       S         290.000000
# V       V         370.000000
# Z       Z         274.000000
# Name: Val_1, dtype: float64

# %%
dd = data.groupby(['Type_1', 'Type_2']).Val_1.mean()

# %%
dd.shape
# Out:
# (16,)

# %%
type(dd)
# Out:
# pandas.core.series.Series

# %%
dd
# Out:
# Type_1  Type_2
# A       B         358
# B       N         189
# D       C         146
# E       H         326
# F       S         361
#         Z         433
# J       E         382
# K       E         271
#         K         417
# N       N         272
#         O         324
# O       O         400
#         U         411
# S       B         290
# V       R         370
# Z       R         274
# Name: Val_1, dtype: int64

# %%
dd.unstack()
# Out:
# Type_2      B      C      E      H      K      N      O      R      S      U  \
# Type_1
# A       358.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# B         NaN    NaN    NaN    NaN    NaN  189.0    NaN    NaN    NaN    NaN
# D         NaN  146.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# E         NaN    NaN    NaN  326.0    NaN    NaN    NaN    NaN    NaN    NaN
# F         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  361.0    NaN
# J         NaN    NaN  382.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# K         NaN    NaN  271.0    NaN  417.0    NaN    NaN    NaN    NaN    NaN
# N         NaN    NaN    NaN    NaN    NaN  272.0  324.0    NaN    NaN    NaN
# O         NaN    NaN    NaN    NaN    NaN    NaN  400.0    NaN    NaN  411.0
# S       290.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# V         NaN    NaN    NaN    NaN    NaN    NaN    NaN  370.0    NaN    NaN
# ...

# %%
dt = pd.read_clipboard()

# %%
dt
# Out:
#    Symbol Type  Value
# 0     APP    F    184
# 1    CSCO    M    176
# 2    MSFT    F     98
# 3     APP    M     97
# 4    CSCO    F    153
# 5    MSFT    M    142
# 6     APP    F    189
# 7    CSCO    M    126
# 8    MSFT    F    109
# 9     APP    M    136
# 10   CSCO    F    117
# 11   MSFT    M    111
# 12    APP    F    121
# 13   CSCO    M    101
# 14   MSFT    F    163
# 15    APP    M    120
# 16   CSCO    F    105
# 17   MSFT    M    174

# %%
dt.groupby(['Symbol', 'Type']).mean()
# Out:
#                   Value
# Symbol Type
# APP    F     164.666667
#        M     117.666667
# CSCO   F     125.000000
#        M     134.333333
# MSFT   F     123.333333
#        M     142.333333

# %%
gpb = dt.groupby(['Symbol', 'Type']).Value.mean()

# %%
gpb.unstack()
# Out:
# Type             F           M
# Symbol
# APP     164.666667  117.666667
# CSCO    125.000000  134.333333
# MSFT    123.333333  142.333333

# %%
mi = dt.groupby(['Symbol', 'Type']).mean()

# %%
mi
# Out:
#                   Value
# Symbol Type
# APP    F     164.666667
#        M     117.666667
# CSCO   F     125.000000
#        M     134.333333
# MSFT   F     123.333333
#        M     142.333333

# %%
mi.loc[('APP', 'F'),:]
# Out:
# Value    164.666667
# Name: (APP, F), dtype: float64

# %%
mi.loc['APP', 'F']
# Out:
# Value    164.666667
# Name: (APP, F), dtype: float64

# %%
mi.index
# Out:
# MultiIndex([( 'APP', 'F'),
#             ( 'APP', 'M'),
#             ('CSCO', 'F'),
#             ('CSCO', 'M'),
#             ('MSFT', 'F'),
#             ('MSFT', 'M')],
#            names=['Symbol', 'Type'])

# %%
mi.unstack()
# Out:
#              Value
# Type             F           M
# Symbol
# APP     164.666667  117.666667
# CSCO    125.000000  134.333333
# MSFT    123.333333  142.333333

# %%
mi.loc['APP', 'M']
# Out:
# Value    117.666667
# Name: (APP, M), dtype: float64

# %%
mi.loc['APP']
# Out:
#            Value
# Type
# F     164.666667
# M     117.666667

# %%
mi
# Out:
#                   Value
# Symbol Type
# APP    F     164.666667
#        M     117.666667
# CSCO   F     125.000000
#        M     134.333333
# MSFT   F     123.333333
#        M     142.333333

# %%
mi.index
# Out:
# MultiIndex([( 'APP', 'F'),
#             ( 'APP', 'M'),
#             ('CSCO', 'F'),
#             ('CSCO', 'M'),
#             ('MSFT', 'F'),
#             ('MSFT', 'M')],
#            names=['Symbol', 'Type'])

# %%
dt
# Out:
#    Symbol Type  Value
# 0     APP    F    184
# 1    CSCO    M    176
# 2    MSFT    F     98
# 3     APP    M     97
# 4    CSCO    F    153
# 5    MSFT    M    142
# 6     APP    F    189
# 7    CSCO    M    126
# 8    MSFT    F    109
# 9     APP    M    136
# 10   CSCO    F    117
# 11   MSFT    M    111
# 12    APP    F    121
# 13   CSCO    M    101
# 14   MSFT    F    163
# 15    APP    M    120
# 16   CSCO    F    105
# 17   MSFT    M    174

# %%
dt2 = dt.copy()

dt2.set_index('Symbol', inplace=True)

dt2
# Out:
#        Type  Value
# Symbol
# APP       F    184
# CSCO      M    176
# MSFT      F     98
# APP       M     97
# CSCO      F    153
# MSFT      M    142
# APP       F    189
# CSCO      M    126
# MSFT      F    109
# APP       M    136
# CSCO      F    117
# MSFT      M    111
# APP       F    121
# CSCO      M    101
# MSFT      F    163
# APP       M    120
# CSCO      F    105
# MSFT      M    174

# %%
dt2.reset_index(inplace=True)

dt2
# Out:
#    Symbol Type  Value
# 0     APP    F    184
# 1    CSCO    M    176
# 2    MSFT    F     98
# 3     APP    M     97
# 4    CSCO    F    153
# 5    MSFT    M    142
# 6     APP    F    189
# 7    CSCO    M    126
# 8    MSFT    F    109
# 9     APP    M    136
# 10   CSCO    F    117
# 11   MSFT    M    111
# 12    APP    F    121
# 13   CSCO    M    101
# 14   MSFT    F    163
# 15    APP    M    120
# 16   CSCO    F    105
# 17   MSFT    M    174

# %%
dt2.reset_index(inplace=True)

dt2.pivot_table(index='Symbol', columns='Type', values='Value')
# Out:
# Type             F           M
# Symbol
# APP     164.666667  117.666667
# CSCO    125.000000  134.333333
# MSFT    123.333333  142.333333

# %%
dt2.drop(columns='index', inplace=True)
dt2
# Out:
#    Symbol Type  Value
# 0     APP    F    184
# 1    CSCO    M    176
# 2    MSFT    F     98
# 3     APP    M     97
# 4    CSCO    F    153
# 5    MSFT    M    142
# 6     APP    F    189
# 7    CSCO    M    126
# 8    MSFT    F    109
# 9     APP    M    136
# 10   CSCO    F    117
# 11   MSFT    M    111
# 12    APP    F    121
# 13   CSCO    M    101
# 14   MSFT    F    163
# 15    APP    M    120
# 16   CSCO    F    105
# 17   MSFT    M    174

# %%
dt3 = dt.copy()
dt3.sort_values(['Symbol', 'Type'], inplace=True)

# %%
dt3
# Out:
#    Symbol Type  Value
# 0     APP    F    184
# 6     APP    F    189
# 12    APP    F    121
# 3     APP    M     97
# 9     APP    M    136
# 15    APP    M    120
# 4    CSCO    F    153
# 10   CSCO    F    117
# 16   CSCO    F    105
# 1    CSCO    M    176
# 7    CSCO    M    126
# 13   CSCO    M    101
# 2    MSFT    F     98
# 8    MSFT    F    109
# 14   MSFT    F    163
# 5    MSFT    M    142
# 11   MSFT    M    111
# 17   MSFT    M    174

# %%
dt3.pivot(index='Symbol', columns='Type', values='Value')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-104-28d14283be91> in <module>
# ----> 1 dt3.pivot(index='Symbol', columns='Type', values='Value')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    5917         from pandas.core.reshape.pivot import pivot
#    5918
# -> 5919         return pivot(self, index=index, columns=columns, values=values)
#    5920
#    5921     _shared_docs[
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot(data, index, columns, values)
#     428         else:
#     429             indexed = data._constructor_sliced(data[values].values, index=index)
# --> 430     return indexed.unstack(columns)
#     431
#     432
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in unstack(self, level, fill_value)
# ...

# %%
dt3
# Out:
#    Symbol Type  Value
# 0     APP    F    184
# 6     APP    F    189
# 12    APP    F    121
# 3     APP    M     97
# 9     APP    M    136
# 15    APP    M    120
# 4    CSCO    F    153
# 10   CSCO    F    117
# 16   CSCO    F    105
# 1    CSCO    M    176
# 7    CSCO    M    126
# 13   CSCO    M    101
# 2    MSFT    F     98
# 8    MSFT    F    109
# 14   MSFT    F    163
# 5    MSFT    M    142
# 11   MSFT    M    111
# 17   MSFT    M    174

# %%
dt
# Out:
#    Symbol Type  Value
# 0     APP    F    184
# 1    CSCO    M    176
# 2    MSFT    F     98
# 3     APP    M     97
# 4    CSCO    F    153
# 5    MSFT    M    142
# 6     APP    F    189
# 7    CSCO    M    126
# 8    MSFT    F    109
# 9     APP    M    136
# 10   CSCO    F    117
# 11   MSFT    M    111
# 12    APP    F    121
# 13   CSCO    M    101
# 14   MSFT    F    163
# 15    APP    M    120
# 16   CSCO    F    105
# 17   MSFT    M    174

# %%
dt.pivot(index="Symbol", columns="Type")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-111-8bacdcfee645> in <module>
# ----> 1 dt.pivot(index="Symbol", columns="Type")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    5917         from pandas.core.reshape.pivot import pivot
#    5918
# -> 5919         return pivot(self, index=index, columns=columns, values=values)
#    5920
#    5921     _shared_docs[
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot(data, index, columns, values)
#     428         else:
#     429             indexed = data._constructor_sliced(data[values].values, index=index)
# --> 430     return indexed.unstack(columns)
#     431
#     432
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in unstack(self, level, fill_value)
# ...

# %%
dt.groupby(['Symbol', 'Type']).Value.sum()
# Out:
# Symbol  Type
# APP     F       494
#         M       353
# CSCO    F       375
#         M       403
# MSFT    F       370
#         M       427
# Name: Value, dtype: int64

# %%
gb = dt.groupby(['Symbol', 'Type']).Value.sum().reset_index()

# %%
gb
# Out:
#   Symbol Type  Value
# 0    APP    F    494
# 1    APP    M    353
# 2   CSCO    F    375
# 3   CSCO    M    403
# 4   MSFT    F    370
# 5   MSFT    M    427

# %%
gb.pivot(index='Symbol', columns='Type', values='Value')
# Out:
# Type      F    M
# Symbol
# APP     494  353
# CSCO    375  403
# MSFT    370  427

# %%
dt.pivot_table(index='Symbol', columns='Type', values='Value', aggfunc=sum)
# Out:
# Type      F    M
# Symbol
# APP     494  353
# CSCO    375  403
# MSFT    370  427

# %%
# pd.melt(df, id_vars=['A'], value_vars=['B', 'C'])
pd.melt(dt, id_vars=['Symbol', 'Type'], value_vars='Value')
# Out:
#    Symbol Type variable  value
# 0     APP    F    Value    184
# 1    CSCO    M    Value    176
# 2    MSFT    F    Value     98
# 3     APP    M    Value     97
# 4    CSCO    F    Value    153
# 5    MSFT    M    Value    142
# 6     APP    F    Value    189
# 7    CSCO    M    Value    126
# 8    MSFT    F    Value    109
# 9     APP    M    Value    136
# 10   CSCO    F    Value    117
# 11   MSFT    M    Value    111
# 12    APP    F    Value    121
# 13   CSCO    M    Value    101
# 14   MSFT    F    Value    163
# 15    APP    M    Value    120
# 16   CSCO    F    Value    105
# 17   MSFT    M    Value    174

# %%
dt
# Out:
#    Symbol Type  Value
# 0     APP    F    184
# 1    CSCO    M    176
# 2    MSFT    F     98
# 3     APP    M     97
# 4    CSCO    F    153
# 5    MSFT    M    142
# 6     APP    F    189
# 7    CSCO    M    126
# 8    MSFT    F    109
# 9     APP    M    136
# 10   CSCO    F    117
# 11   MSFT    M    111
# 12    APP    F    121
# 13   CSCO    M    101
# 14   MSFT    F    163
# 15    APP    M    120
# 16   CSCO    F    105
# 17   MSFT    M    174

# %%
pvt_dt = dt.pivot_table(index='Symbol', columns='Type', values='Value', aggfunc=sum)
